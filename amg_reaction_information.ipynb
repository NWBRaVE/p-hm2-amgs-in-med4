# %%
import json
import cobra

# %%
model = cobra.io.read_sbml_model("model_files/ProchlorococcusMED4v1.xml")
amgs = json.loads(open("model_files/amg_reactions.json").read())
manual_relabels = json.loads(open("model_files/subsystem_alias.json").read())
amg_names = json.loads(open("model_files/amg_gene_map.json").read())

# %%
for reaction in sorted(model.reactions, key=str):
    if reaction.id in amgs:
        gene = amg_names[reaction.id]
        ss = manual_relabels[reaction.subsystem]
        met_names = {}
        for mets in reaction.metabolites:
            met_names[mets.id] = f"[{mets.name}]"
        rxn_str = str(reaction)
        for m, n in met_names.items():
            rxn_str = rxn_str.replace(m, n)
        if rxn_str.endswith("<=> "):
            rxn_str = rxn_str + "⌀"
        rxn_str = rxn_str.replace("<=>", r"\rightleftharpoons\newline")
        rxn_str = rxn_str.replace("-->", r"\harpoon\newline")
        rxn_str = rxn_str.replace(":", f" ({gene}) &")
        print(f"{rxn_str} & {ss}" + r"\\\hline")
# Out:
# FAKEOrthophosphateEX (phoH) & [Orthophosphate] \rightleftharpoons\newline ⌀ & Exchange\\\hline
# PSIIabs (psbA/psbD) & [Photon] \harpoon\newline [Photon absorbed by PSII] & Photosynthesis\\\hline
# R00311 (ho1) & [Heme] + 3.0 [Oxygen] + 3.0 [Plastoquinol] \harpoon\newline [Biliverdin] + [CO] + [Fe2+] + 3.0 [H2O] + 3.0 [Plastoquinone] & Porphyrin / Chlorophyll\\\hline
# R00426 (mazG) & [GTP] + [H2O] \harpoon\newline [Diphosphate] + [GMP] & Purine\\\hline
# R00662 (mazG) & [H2O] + [UTP] \harpoon\newline [Diphosphate] + [UMP] & Pyrimidine\\\hline
# R01063 (cp12) & [D-Glyceraldehyde 3-phosphate] + [NADP+] + [Orthophosphate] \rightleftharpoons\newline [3-Phospho-D-glyceroyl phosphate] + [H+] + [NADPH] & Unspecified\\\hline
# R01523 (cp12) & [ATP] + [D-Ribulose 5-phosphate] \rightleftharpoons\newline [ADP] + [D-Ribulose 1_5-bisphosphate] & Carbon fixation\\\hline
# R01827 (talC) & [D-Glyceraldehyde 3-phosphate] + [Sedoheptulose 7-phosphate] \rightleftharpoons\newline [D-Erythrose 4-phosphate] + [D-Fructose 6-phosphate] & Pentose Phosphate\\\hline
# R01855 (mazG) & [H2O] + [dGTP] \harpoon\newline [Diphosphate] + [dGMP] & Purine\\\hline
# R02017 (nrdA) & [ADP] + [Thioredoxin] \harpoon\newline [H2O] + [Thioredoxin disulfide] + d[ADP] & Purine\\\hline
# R02018 (nrdA) & [H2O] + [Thioredoxin disulfide] + [dUDP] \rightleftharpoons\newline [Thioredoxin] + [UDP] & Unspecified\\\hline
# R02019 (nrdA) & [GDP] + [Thioredoxin] \harpoon\newline [H2O] + [Thioredoxin disulfide] + d[GDP] & Purine\\\hline
# R02024 (nrdA) & [CDP] + [Thioredoxin] \harpoon\newline [H2O] + [Thioredoxin disulfide] + d[CDP] & Pyrimidine\\\hline
# R02100 (mazG) & [H2O] + [dUTP] \harpoon\newline [Diphosphate] + [dUMP] & Pyrimidine\\\hline
# R05223 (cobS) & [Adenosine-GDP-cobinamide] + [alpha-Ribazole] \harpoon\newline [Cobamide coenzyme] + [GMP] + [H+] & Porphyrin / Chlorophyll\\\hline
# R05817 (pebS) & [Biliverdin] + [Reduced ferredoxin] \harpoon\newline [(3Z)-Phycocyanobilin] + [Oxidized ferredoxin] & Porphyrin / Chlorophyll\\\hline
# R05818 (cpeT/cpcT) & [Biliverdin] + [Reduced ferredoxin] \harpoon\newline [15_16-Dihydrobiliverdin] + [Oxidized ferredoxin] & Porphyrin / Chlorophyll\\\hline
